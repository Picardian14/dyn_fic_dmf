# %%
import sys
import os
import argparse
import math
import time
from scipy.signal import butter, lfilter
import fastdyn_fic_dmf as dmf
import numpy as np
from scipy.io import loadmat
from helper_functions import filter_bold
from multiprocessing import Pool
from scipy.stats import gamma  # Import gamma for entropy calculation


def calculate_gamma_entropy(node_index, rates):
    print(f"Processing node {node_index}")
    # Fit a gamma distribution to the data
    alpha, loc, beta = gamma.fit(rates)
    # Calculate the entropy of the gamma distribution
    entropy_value = gamma.entropy(a=alpha, loc=loc, scale=beta)
    return node_index, alpha, loc, beta, entropy_value

def grid_step(args):
    """
    Processes a single SEED and returns the entropy results.
    """
    SEED_tuple, params, nb_steps, burnout, overlap, isubfcd, a, b = args
    idx_SEED, SEED = SEED_tuple
    params['seed'] = SEED
    entropy_per_region = {}
    # Statistical FC
    params['G'] = loadmat('../matlab/Results/stat_fc/results_awake_stat_fc.mat')['minEstimatedG_Awake']
    params['alpha'] = loadmat('../matlab/Results/stat_fc/results_awake_stat_fc.mat')['minEstimatedY_Awake']
    params['J'] = params['alpha'] * params['G'] * params['C'].sum(axis=0).squeeze() + 1
    params["with_plasticity"] = False
    params["with_decay"] = False
    rates, _, _, _ = dmf.run(params, nb_steps)
    
    entropy_stat = []
    for node in range(params['N']):
        node_rates = rates[:, node]
        _, _, _, _, entropy = calculate_gamma_entropy(node, node_rates.reshape(rates.shape[0], -1))
        entropy_stat.append(entropy)
    stat_entropy = np.array(entropy_stat)
    # Dynamic FC
    params['G'] = loadmat('../matlab/Results/dyn_fc/results_awake_dyn_fc.mat')['minEstimatedG_Awake']
    params['lrj'] = loadmat('../matlab/Results/dyn_fc/results_awake_dyn_fc.mat')['minEstimatedY_Awake']
    DECAY = np.exp(a + np.log(params['lrj']) * b)
    params['taoj'] = DECAY
    params['alpha'] = 0.75
    params["with_plasticity"] = True
    params["with_decay"] = True
    params['J'] = params['alpha'] * params['G'] * params['C'].sum(axis=0).squeeze() + 1
    rates, _, _, _ = dmf.run(params, nb_steps)

    entropy_dyn = []
    for node in range(params['N']):
        node_rates = rates[:, node]
        _, _, _, _, entropy = calculate_gamma_entropy(node, node_rates.reshape(rates.shape[0], -1))
        entropy_dyn.append(entropy)
    dyn_entropy = np.array(entropy_dyn)

    return idx_SEED,stat_entropy,dyn_entropy
    

    
# Prepare parameters and data
C = loadmat('./data/DTI_fiber_consensus_HCP.mat')['connectivity'][:200, :200]
C = 0.2 * C / np.max(C)
params = dmf.default_params(C=C)

isubfcd = np.triu_indices(C.shape[1], 1)
params['N'] = C.shape[0]

params["return_rate"] = True
params["return_bold"] = True
params["return_fic"] = True

burnout = 7
params["flp"] = 0.01
params["fhp"] = 0.1
params["wsize"] = 30
overlap = 29
params['TR'] = 2


params['dtt'] = 0.001  # Assuming 'dtt' is defined; adjust as needed
nb_steps = 50000

fit_res = np.load("./data/fit_res_3-44.npy", allow_pickle=True)
b = fit_res[0]  # First element is the slope
a = fit_res[1]

SEED_range = list(range(1, 101))  # SEEDs from 1 to 100

NUM_CORES = 24  # Number of cores per node

OBJ_RATE = 3.44
params['obj_rate'] = OBJ_RATE

task_args = [((idx_SEED, SEED), params.copy(), nb_steps, burnout, overlap, isubfcd, a, b)
            for idx_SEED, SEED in enumerate(SEED_range)]

# Define the folder to save partial results
results_folder = "./Results/EntropySimulation"
os.makedirs(results_folder, exist_ok=True)

# Process assigned SEEDs using multiprocessing Pool
with Pool(processes=NUM_CORES) as pool:
    results = pool.map(grid_step, task_args)
    
# Separate the res to keep the entropy vectors
stat_entropy = []
dyn_entropy = []
for res in results:
    idx_SEED, stat_ent, dyn_ent = res
    stat_entropy.append(stat_ent)
    dyn_entropy.append(dyn_ent)
stat_entropy = np.array(stat_entropy)
dyn_entropy = np.array(dyn_entropy)
# Save the entropy vectors
file = os.path.join(results_folder, f"stat_entropy.npy")
np.save(file, stat_entropy)
file = os.path.join(results_folder, f"dyn_entropy.npy")
np.save(file, dyn_entropy)
# Out:
# Debuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldDebuging boldProcessing node 0
# Processing node 0
# Processing node 0
# Processing node 0Processing node 0
#
# Processing node 0
# Processing node 0
# Processing node 1
# Processing node 0
# Processing node 1
# Processing node 0Processing node 2
#
# Processing node 0Processing node 1
#
# Processing node 1
# Processing node 1
# Processing node 1Processing node 1
#
# Processing node 0Processing node 2
#
# Processing node 3
# Processing node 2
# Processing node 0
# Processing node 1
# Processing node 4
# Processing node 2Processing node 3
#
# Processing node 3Processing node 2
#
# Processing node 5
# Processing node 2
# Processing node 4Processing node 3
#
# Processing node 2
# Processing node 4
# Processing node 1
# Processing node 6Processing node 1
#
# Processing node 2
# Processing node 4
# Processing node 5Processing node 3Processing node 3Processing node 1Processing node 5Processing node 3Processing node 7
#
#
#
#
#
# Processing node 3
# Processing node 1
#
# Processing node 2
# Processing node 6
# Processing node 4
# Processing node 4
# Processing node 8
# Processing node 5
# Processing node 6
# Processing node 4
# Processing node 4
# Processing node 2
# Processing node 5
# Processing node 5
# Processing node 7
# Processing node 6
# Processing node 3Processing node 7
#
# Processing node 5
# Processing node 5
# Processing node 6
# Processing node 6
# Processing node 2
# Processing node 8Processing node 2
#
# Processing node 3
# Processing node 4Processing node 7Processing node 6
#
#
# Processing node 6
# Processing node 7
# Processing node 7
# Processing node 9
# Processing node 7
# Processing node 5Processing node 3
#
# Processing node 8Processing node 8
#
# Processing node 4
# Processing node 9
# Processing node 7
# Processing node 10
# Processing node 8
# Processing node 4
# Processing node 8
# Processing node 9
# Processing node 3Processing node 5
#
# Processing node 9
# Processing node 8Processing node 6
#
# Processing node 11Processing node 8Processing node 10
#
#
# Processing node 9
# Processing node 5
# Processing node 6
# Processing node 10
# Processing node 7
# Processing node 4
# Processing node 6
# Processing node 8Processing node 11
#
# Processing node 7
# Processing node 5
# Processing node 11
# Processing node 7
# Processing node 10
# Processing node 10
# Processing node 9
# Processing node 6
# Processing node 9Processing node 8
#
# Processing node 12
# Processing node 9Processing node 9
#
# Processing node 8
# Processing node 10Processing node 7
#
# Processing node 13
# Processing node 12
# Processing node 10
# Processing node 9Processing node 9
#
# Processing node 8
# Processing node 14
# Processing node 11
# Processing node 9
# Processing node 10Processing node 11Processing node 10
#
#
# Processing node 12
# Processing node 11
# Processing node 10
# Processing node 10Processing node 10Processing node 12
#
#
# Processing node 11
# Processing node 13
# Processing node 11Processing node 13
#
# Processing node 15
# Processing node 11
# Processing node 12
# Processing node 14
# Processing node 13
# Processing node 12Processing node 11
#
# Processing node 16
# Processing node 12Processing node 13Processing node 11
#
#
# Processing node 14
# Processing node 11Processing node 14
#
# Processing node 12
# Processing node 14
# Processing node 12
# Processing node 0Processing node 15
#
# Processing node 12Processing node 13
# Processing node 12
#
# Processing node 17
# Processing node 15
# Processing node 12Processing node 15
# Processing node 16
#
# Processing node 13
# Processing node 15
# Processing node 13
# Processing node 18
# Processing node 16
# Processing node 13
# Processing node 17
# Processing node 0
# Processing node 0Processing node 19
#
# Processing node 14Processing node 13
#
# Processing node 18
# Processing node 13
# Processing node 17
# Processing node 0
# Processing node 14
# Processing node 0Processing node 1
#
# Processing node 14Processing node 19
# Processing node 16
#
# Processing node 13
# Processing node 0
# Processing node 16
# Processing node 14
# Processing node 14
# Processing node 20Processing node 14
#
# Processing node 17
# Processing node 0Processing node 1
#
# Processing node 20
# Processing node 0Processing node 1
#
# Processing node 15Processing node 0Processing node 1
#
#
# Processing node 18
# Processing node 2
# Processing node 1
# Processing node 15
# Processing node 2Processing node 14
#
# Processing node 15Processing node 17
#
# Processing node 2
# Processing node 18
# Processing node 15
# Processing node 2
# Processing node 3
# Processing node 1
# Processing node 15Processing node 21Processing node 15
#
# Processing node 18
#
# Processing node 2
# Processing node 3
# Processing node 1Processing node 4
#
# Processing node 3Processing node 3Processing node 21
#
#
# Processing node 1Processing node 16Processing node 1
#
#
# Processing node 4
# Processing node 19
# Processing node 19Processing node 5
#
# Processing node 2Processing node 4Processing node 4
#
#
# Processing node 16
# Processing node 16
# Processing node 3Processing node 15
#
# Processing node 5
# Processing node 16
# Processing node 6
# Processing node 5Processing node 16
#
# Processing node 2Processing node 5
#
# Processing node 19
# Processing node 3
# Processing node 16
# Processing node 22Processing node 4
#
# Processing node 6
# Processing node 7
# Processing node 6Processing node 6Processing node 2
#
#
# Processing node 2Processing node 22Processing node 3
#
# Processing node 20
#
# Processing node 5
# Processing node 17
# Processing node 20Processing node 4
#
# Processing node 17
# Processing node 7
# Processing node 3Processing node 7Processing node 8
#
#
# Processing node 16Processing node 6
# Processing node 17
#
# Processing node 5Processing node 17
# Processing node 4
# Processing node 7Processing node 3
#
#
# Processing node 0
# Processing node 17
# Processing node 17
# Processing node 8
# Processing node 4
# Processing node 8
# Processing node 6Processing node 17Processing node 7
# Processing node 18Processing node 20
#
#
#
# Processing node 4
# Processing node 8
# Processing node 23
# Processing node 5
# Processing node 23
# Processing node 5
# Processing node 9
# Processing node 18
# Processing node 5
# Processing node 21
# Processing node 8
# Processing node 9Processing node 18Processing node 7
#
#
# Processing node 21
# Processing node 6
# Processing node 18
# Processing node 18
# Processing node 6Processing node 9Processing node 6
#
#
# Processing node 9
# Processing node 7Processing node 1
#
# Processing node 21
# Processing node 18
# Processing node 19Processing node 9
# Processing node 24Processing node 18
#
#
# Processing node 7Processing node 7
#
# Processing node 10
# Processing node 19
# Processing node 24Processing node 8
#
# Processing node 22
# Processing node 10
# Processing node 25
# Processing node 0Processing node 0
#
# Processing node 19
# Processing node 22
# Processing node 19
# Processing node 8
# Processing node 9
# Processing node 8Processing node 22Processing node 19
#
#
# Processing node 26
# Processing node 19Processing node 8
#
# Processing node 20Processing node 19
#
# Processing node 2
# Processing node 10
# Processing node 10
# Processing node 10
# Processing node 9
# Processing node 20
# Processing node 23
# Processing node 11
# Processing node 25
# Processing node 11
# Processing node 10
# Processing node 3
# Processing node 10Processing node 1
#
# Processing node 20
# Processing node 23
# Processing node 1
# Processing node 20
# Processing node 20Processing node 27
#
# Processing node 9Processing node 23
#
# Processing node 4
# Processing node 20
# Processing node 21
# Processing node 20
# Processing node 21
# Processing node 11
# Processing node 11Processing node 9Processing node 11
#
#
# Processing node 11
# Processing node 12Processing node 24
#
# Processing node 10Processing node 5
#
# Processing node 11
# Processing node 21
# Processing node 12
# Processing node 26
# Processing node 13
# Processing node 2
# Processing node 2
# Processing node 6
# Processing node 21Processing node 21
#
# Processing node 28
# Processing node 21
# Processing node 24
# Processing node 24Processing node 14
#
# Processing node 7
# Processing node 12Processing node 22
#
# Processing node 3
# Processing node 29
# Processing node 12Processing node 3
#
# Processing node 12Processing node 21
#
# Processing node 22Processing node 25
#
# Processing node 10
# Processing node 13
# Processing node 11Processing node 15
#
# Processing node 8
# Processing node 12
# Processing node 12
# Processing node 4
# Processing node 22Processing node 27Processing node 4
#
#
# Processing node 23
# Processing node 22Processing node 9
#
# Processing node 13
# Processing node 25
# Processing node 5
# Processing node 22
# Processing node 22
# Processing node 23Processing node 30Processing node 5Processing node 25
#
#
#
# Processing node 10
# Processing node 26
# Processing node 22Processing node 11
#
# Processing node 16
# Processing node 6
# Processing node 13Processing node 23Processing node 12
#
# Processing node 13
#
# Processing node 14
# Processing node 14
# Processing node 23
# Processing node 6
# Processing node 13
# Processing node 24Processing node 24
#
# Processing node 13
# Processing node 7
# Processing node 28Processing node 23
#
# Processing node 24
# Processing node 7
# Processing node 14
# Processing node 23
# Processing node 26
# Processing node 12
# Processing node 11
# Processing node 17Processing node 23
#
# Processing node 14
# Processing node 26
# Processing node 24
# Processing node 15
# Processing node 27
# Processing node 15
# Processing node 31
# Processing node 13
# Processing node 13
# Processing node 16
# Processing node 25
# Processing node 14
# Processing node 24
# Processing node 25
# Processing node 14Processing node 25
# Processing node 15
# Processing node 8
#
# Processing node 14
# Processing node 29Processing node 24
# Processing node 12
#
# Processing node 26
# Processing node 8
# Processing node 15
# Processing node 18
# Processing node 27
# Processing node 25
# Processing node 32Processing node 15
#
# Processing node 28
# Processing node 24
# Processing node 27
# Processing node 27
# Processing node 17
# Processing node 16
# Processing node 14
# Processing node 28Processing node 25Processing node 26
#
#
# Processing node 15Processing node 18
#
# Processing node 25
# Processing node 26
# Processing node 16
# Processing node 9Processing node 15
#
# Processing node 13
# Processing node 16Processing node 30
# Processing node 16
#
# Processing node 25
# Processing node 9
# Processing node 16Processing node 10
# Processing node 28
#
# Processing node 19
# Processing node 16
# Processing node 28
# Processing node 26
# Processing node 29Processing node 17Processing node 33
#
#
# Processing node 17
# Processing node 14
# Processing node 26
# Processing node 19Processing node 11
#
# Processing node 26
# Processing node 15
# Processing node 27
# Processing node 29
# Processing node 17
# Processing node 27Processing node 12
#
# Processing node 17Processing node 27
#
# Processing node 20
# Processing node 29
# Processing node 31Processing node 17Processing node 29
#
#
# Processing node 26Processing node 30
#
# Processing node 10
# Processing node 17Processing node 18
#
# Processing node 15Processing node 18
#
# Processing node 34
# Processing node 27
# Processing node 16
# Processing node 28
# Processing node 18
# Processing node 27
# Processing node 30
# Processing node 20
# Processing node 13
# Processing node 30
# Processing node 28
# Processing node 21
# Processing node 32
# Processing node 11
# Processing node 31Processing node 18
#
# Processing node 18Processing node 30Processing node 35
#
#
# Processing node 27
# Processing node 19
# Processing node 17
# Processing node 28
# Processing node 18
# Processing node 19
# Processing node 16
# Processing node 19
# Processing node 28Processing node 28
#
# Processing node 31Processing node 20
#
# Processing node 21Processing node 14
#
# Processing node 29Processing node 22
# Processing node 33
#
# Processing node 31
# Processing node 12
# Processing node 29
# Processing node 32
# Processing node 19Processing node 18
#
# Processing node 19
# Processing node 31
# Processing node 36
# Processing node 19Processing node 20
#
# Processing node 28
# Processing node 29Processing node 20
#
# Processing node 29
# Processing node 17
# Processing node 29
# Processing node 21
# Processing node 34
# Processing node 32
# Processing node 32
# Processing node 22
# Processing node 15
# Processing node 30Processing node 23
#
# Processing node 20
# Processing node 13
# Processing node 30
# Processing node 33
# Processing node 20
# Processing node 19
# Processing node 32Processing node 21
#
# Processing node 30Processing node 37
#
# Processing node 20
# Processing node 21Processing node 30
#
# Processing node 29
# Processing node 35
# Processing node 33
# Processing node 18
# Processing node 30
# Processing node 16
# Processing node 33
# Processing node 23
# Processing node 34
# Processing node 31
# Processing node 22
# Processing node 34
# Processing node 21
# Processing node 21
# Processing node 14
# Processing node 31
# Processing node 21
# Processing node 31
# Processing node 20
# Processing node 36
# Processing node 33Processing node 22
#
# Processing node 38
# Processing node 17
# Processing node 22
# Processing node 31
# Processing node 22Processing node 31
#
# Processing node 30
# Processing node 32
# Processing node 19
# Processing node 34
# Processing node 31Processing node 24
#
# Processing node 23
# Processing node 24Processing node 33
# Processing node 23
#
# Processing node 22Processing node 22
#
# Processing node 35
# Processing node 15
# Processing node 34Processing node 21
# Processing node 32
#
# Processing node 39
# Processing node 37Processing node 35
#
# Processing node 23Processing node 24
#
# Processing node 34Processing node 32
#
# Processing node 32
# Processing node 22
# Processing node 23Processing node 18
# Processing node 35
#
# Processing node 24
# Processing node 32
# Processing node 25
# Processing node 35Processing node 25Processing node 20
#
#
# Processing node 36
# Processing node 25Processing node 32
#
# Processing node 35
# Processing node 21
# Processing node 23
# Processing node 24
# Processing node 25
# Processing node 33
# Processing node 36
# Processing node 23Processing node 37
#
# Processing node 16
# Processing node 33
# Processing node 40
# Processing node 38
# Processing node 36
# Processing node 23
# Processing node 33
# Processing node 24
# Processing node 33
# Processing node 34
# Processing node 24
# Processing node 19Processing node 25
#
# Processing node 26
# Processing node 36
# Processing node 34Processing node 26
#
# Processing node 37
# Processing node 17Processing node 33Processing node 38
#
#
# Processing node 39Processing node 36
#
# Processing node 22
# Processing node 27
# Processing node 25Processing node 26
#
# Processing node 41
# Processing node 37
# Processing node 24Processing node 24Processing node 37
#
#
# Processing node 26
# Processing node 35Processing node 34
#
# Processing node 34Processing node 25
# Processing node 38
# Processing node 35
#
# Processing node 38
# Processing node 18
# Processing node 40
# Processing node 26
# Processing node 37
# Processing node 42
# Processing node 27
# Processing node 36Processing node 34
#
# Processing node 23
# Processing node 39Processing node 28
#
# Processing node 26
# Processing node 36Processing node 25
# Processing node 27
#
# Processing node 37
# Processing node 38
# Processing node 26
# Processing node 25Processing node 41Processing node 20Processing node 27
#
# Processing node 28
#
#
# Processing node 19Processing node 38
#
# Processing node 35Processing node 39
#
# Processing node 27Processing node 39
#
# Processing node 35
# Processing node 35
# Processing node 43
# Processing node 24
# Processing node 26Processing node 29
#
# Processing node 40
# Processing node 42
# Processing node 28
# Processing node 44
# Processing node 29
# Processing node 20
# Processing node 39Processing node 40
#
# Processing node 40
# Processing node 28
# Processing node 38
# Processing node 27Processing node 37
#
# Processing node 36
# Processing node 45
# Processing node 26
# Processing node 39Processing node 39Processing node 28
#
#
# Processing node 30
# Processing node 36
# Processing node 25
# Processing node 27
# Processing node 43Processing node 21
#
# Processing node 40Processing node 27
#
# Processing node 41Processing node 40
#
# Processing node 36Processing node 41
#
# Processing node 28
# Processing node 37
# Processing node 29Processing node 38Processing node 21
#
#
# Processing node 27Processing node 30
#
# Processing node 41
# Processing node 40
# Processing node 41
# Processing node 29
# Processing node 29Processing node 46
#
# Processing node 26
# Processing node 42
# Processing node 37Processing node 41
# Processing node 22
#
# Processing node 42Processing node 28
#
# Processing node 44Processing node 37
#
# Processing node 31
# Processing node 39
# Processing node 42
# Processing node 38
# Processing node 31
# Processing node 28Processing node 41
#
# Processing node 30
# Processing node 42
# Processing node 29
# Processing node 40
# Processing node 30
# Processing node 22
# Processing node 30
# Processing node 28
# Processing node 47
# Processing node 31
# Processing node 41
# Processing node 43Processing node 27
#
# Processing node 38
# Processing node 23
# Processing node 42Processing node 32
#
# Processing node 38Processing node 43
#
# Processing node 32
# Processing node 39
# Processing node 45
# Processing node 43
# Processing node 29Processing node 29
# Processing node 44
#
# Processing node 43
# Processing node 23Processing node 28
#
# Processing node 32Processing node 42
#
# Processing node 31
# Processing node 31
# Processing node 30
# Processing node 30
# Processing node 29
# Processing node 29Processing node 44
#
# Processing node 39
# Processing node 42Processing node 39
#
# Processing node 43
# Processing node 40Processing node 30
#
# Processing node 46
# Processing node 33
# Processing node 44
# Processing node 45
# Processing node 24
# Processing node 31Processing node 31
#
# Processing node 33
# Processing node 44
# Processing node 24
# Processing node 43
# Processing node 30
# Processing node 32Processing node 32
#
# Processing node 48
# Processing node 43Processing node 30
#
# Processing node 40
# Processing node 33
# Processing node 45
# Processing node 47
# Processing node 45
# Processing node 34
# Processing node 31Processing node 41
#
# Processing node 32
# Processing node 45
# Processing node 44
# Processing node 46Processing node 25
#
# Processing node 40Processing node 49
#
# Processing node 31
# Processing node 33
# Processing node 34Processing node 33Processing node 32
#
#
# Processing node 35Processing node 44
#
# Processing node 25
# Processing node 31
# Processing node 46
# Processing node 45
# Processing node 41
# Processing node 46
# Processing node 36
# Processing node 34
# Processing node 44
# Processing node 47Processing node 48Processing node 46Processing node 42
#
#
#
# Processing node 46
# Processing node 50Processing node 37
#
# Processing node 32Processing node 26
#
# Processing node 32Processing node 33
#
# Processing node 41
# Processing node 33
# Processing node 47
# Processing node 47Processing node 34
#
# Processing node 32
# Processing node 45
# Processing node 35
# Processing node 35
# Processing node 35
# Processing node 34
# Processing node 42
# Processing node 26
# Processing node 47Processing node 47
#
# Processing node 38
# Processing node 45Processing node 51
# Processing node 43
#
# Processing node 36
# Processing node 48
# Processing node 42Processing node 49
#
# Processing node 34Processing node 48
#
# Processing node 33
# Processing node 33
# Processing node 27
# Processing node 39
# Processing node 34
# Processing node 48
# Processing node 49
# Processing node 33
# Processing node 43
# Processing node 36
# Processing node 46
# Processing node 36
# Processing node 48Processing node 40
#
# Processing node 50
# Processing node 35Processing node 46
#
# Processing node 44Processing node 50
#
# Processing node 27
# Processing node 48
# Processing node 51
# Processing node 41
# Processing node 49
# Processing node 52
# Processing node 35Processing node 37
#
# Processing node 43
# Processing node 51Processing node 35Processing node 52
#
#
# Processing node 34Processing node 34
#
# Processing node 34
# Processing node 37
# Processing node 28
# Processing node 49Processing node 45Processing node 49
#
# Processing node 47
#
# Processing node 52Processing node 47
#
# Processing node 44
# Processing node 37Processing node 36
#
# Processing node 53Processing node 50
#
# Processing node 42
# Processing node 36
# Processing node 36Processing node 28
# Processing node 45
#
# Processing node 49
# Processing node 35
# Processing node 46
# Processing node 50
# Processing node 35
# Processing node 53Processing node 44
#
# Processing node 51Processing node 38Processing node 29
#
#
# Processing node 37
# Processing node 54
# Processing node 35
# Processing node 38
# Processing node 48
# Processing node 38Processing node 50
#
# Processing node 37
# Processing node 53
# Processing node 43Processing node 48
#
# Processing node 29Processing node 50Processing node 46Processing node 36
#
#
#
# Processing node 38
# Processing node 51
# Processing node 38
# Processing node 39
# Processing node 54
# Processing node 47
# Processing node 39
# Processing node 52
# Processing node 36Processing node 45
#
# Processing node 39
# Processing node 30
# Processing node 54
# Processing node 36
# Processing node 51
# Processing node 49
# Processing node 48
# Processing node 40
# Processing node 46
# Processing node 52
# Processing node 52
# Processing node 37
# Processing node 49
# Processing node 40
# Processing node 51Processing node 39Processing node 55
# Processing node 41
#
#
# Processing node 39
# Processing node 53Processing node 30Processing node 37
#
#
# Processing node 42
# Processing node 40
# Processing node 44
# Processing node 41
# Processing node 31
# Processing node 47
# Processing node 37
# Processing node 55Processing node 37
#
# Processing node 49
# Processing node 47
# Processing node 55
# Processing node 43
# Processing node 50Processing node 53
# Processing node 54
#
# Processing node 52
# Processing node 48
# Processing node 50
# Processing node 53
# Processing node 56
# Processing node 38Processing node 55
#
# Processing node 53
# Processing node 40
# Processing node 41
# Processing node 31Processing node 40Processing node 56
# Processing node 48
#
#
# Processing node 56
# Processing node 38
# Processing node 38
# Processing node 42
# Processing node 45
# Processing node 50Processing node 38
#
# Processing node 44
# Processing node 57
# Processing node 56
# Processing node 49
# Processing node 51
# Processing node 43Processing node 54
# Processing node 41
#
# Processing node 32Processing node 45
#
# Processing node 54
# Processing node 58
# Processing node 41
# Processing node 52
# Processing node 49
# Processing node 57
# Processing node 42Processing node 39Processing node 54
#
#
# Processing node 39Processing node 46
#
# Processing node 51Processing node 39
#
# Processing node 42
# Processing node 53Processing node 57
#
# Processing node 57
# Processing node 43
# Processing node 55
# Processing node 50
# Processing node 46Processing node 51
#
# Processing node 39
# Processing node 55Processing node 54
#
# Processing node 33
# Processing node 44
# Processing node 32
# Processing node 44
# Processing node 50Processing node 40
# Processing node 58Processing node 51
#
# Processing node 55
#
# Processing node 55Processing node 56
#
# Processing node 59
# Processing node 42Processing node 47
#
# Processing node 58
# Processing node 45
# Processing node 40Processing node 58
# Processing node 56
#
# Processing node 40
# Processing node 43
# Processing node 52Processing node 47
#
# Processing node 34
# Processing node 45
# Processing node 52
# Processing node 40Processing node 53
# Processing node 52
#
# Processing node 51
# Processing node 41Processing node 41
#
# Processing node 33
# Processing node 48
# Processing node 60
# Processing node 56Processing node 56
#
# Processing node 57
# Processing node 57
# Processing node 46
# Processing node 42Processing node 41Processing node 59
# Processing node 61
#
#
# Processing node 43Processing node 44
#
# Processing node 53
# Processing node 46
# Processing node 59
# Processing node 47Processing node 48
#
# Processing node 59
# Processing node 41Processing node 35
#
# Processing node 53
# Processing node 57
# Processing node 52
# Processing node 58Processing node 58
#
# Processing node 49Processing node 57
#
# Processing node 34
# Processing node 45
# Processing node 54
# Processing node 47
# Processing node 60Processing node 60
#
# Processing node 62
# Processing node 48
# Processing node 44Processing node 43
#
# Processing node 42Processing node 42
#
# Processing node 59
# Processing node 49Processing node 42
# Processing node 54
#
# Processing node 63
# Processing node 49Processing node 36
# Processing node 60
#
# Processing node 54
# Processing node 53
# Processing node 58
# Processing node 50
# Processing node 58
# Processing node 55
# Processing node 64Processing node 35Processing node 59
#
#
# Processing node 46Processing node 55
#
# Processing node 61
# Processing node 61
# Processing node 60
# Processing node 45
# Processing node 61
# Processing node 62Processing node 48
#
# Processing node 43
# Processing node 59
# Processing node 44
# Processing node 59Processing node 55
#
# Processing node 37Processing node 46
#
# Processing node 43
# Processing node 50
# Processing node 50
# Processing node 56
# Processing node 36Processing node 43
#
# Processing node 54Processing node 51
#
# Processing node 56Processing node 60
#
# Processing node 65
# Processing node 47
# Processing node 60
# Processing node 61
# Processing node 48
# Processing node 62
# Processing node 62
# Processing node 44Processing node 63Processing node 49
#
#
# Processing node 44Processing node 60
#
# Processing node 38
# Processing node 51
# Processing node 45
# Processing node 51
# Processing node 47
# Processing node 44
# Processing node 57Processing node 52
#
# Processing node 52
# Processing node 56Processing node 37
#
# Processing node 61Processing node 55
#
# Processing node 66
# Processing node 63Processing node 61Processing node 45
#
#
# Processing node 63
# Processing node 53
# Processing node 45
# Processing node 62
# Processing node 49
# Processing node 39
# Processing node 46Processing node 46
# Processing node 45
#
# Processing node 50Processing node 64
# Processing node 61
#
# Processing node 48
# Processing node 52Processing node 58
#
# Processing node 38
# Processing node 56
# Processing node 62
# Processing node 53
# Processing node 62
# Processing node 57Processing node 63Processing node 46
#
#
# Processing node 67
# Processing node 64
# Processing node 64Processing node 54Processing node 63
#
#
# Processing node 62Processing node 65
#
# Processing node 49
# Processing node 50
# Processing node 47
# Processing node 65
# Processing node 40
# Processing node 63Processing node 46Processing node 47
#
#
# Processing node 64
# Processing node 59
# Processing node 53
# Processing node 39Processing node 66Processing node 57
#
#
# Processing node 51Processing node 64
#
# Processing node 65
# Processing node 54
# Processing node 55Processing node 68
#
# Processing node 67
# Processing node 57
# Processing node 63
# Processing node 58
# Processing node 50
# Processing node 47
# Processing node 52Processing node 66
#
# Processing node 48
# Processing node 48
# Processing node 51
# Processing node 41Processing node 65
#
# Processing node 54
# Processing node 47
# Processing node 65
# Processing node 60Processing node 55
#
# Processing node 40
# Processing node 58
# Processing node 64
# Processing node 52
# Processing node 66
# Processing node 64Processing node 48
#
# Processing node 51Processing node 58
#
# Processing node 69
# Processing node 56
# Processing node 68
# Processing node 41
# Processing node 53
# Processing node 53
# Processing node 59
# Processing node 67
# Processing node 48
# Processing node 69Processing node 42Processing node 54
#
# Processing node 66
#
# Processing node 66
# Processing node 59Processing node 42
#
# Processing node 49
# Processing node 49
# Processing node 61
# Processing node 55
# Processing node 49
# Processing node 56Processing node 43
#
# Processing node 70Processing node 59
#
# Processing node 57
# Processing node 54
# Processing node 65
# Processing node 50
# Processing node 67
# Processing node 65
# Processing node 49
# Processing node 52
# Processing node 68
# Processing node 70
# Processing node 58
# Processing node 71
# Processing node 55Processing node 43
#
# Processing node 67
# Processing node 60Processing node 68
#
# Processing node 62
# Processing node 67
# Processing node 55
# Processing node 59
# Processing node 56Processing node 57
#
# Processing node 60
# Processing node 72Processing node 60
#
# Processing node 50
# Processing node 66
# Processing node 44Processing node 50
#
# Processing node 66
# Processing node 71
# Processing node 69
# Processing node 51
# Processing node 61
# Processing node 68Processing node 44
#
# Processing node 50
# Processing node 53
# Processing node 56
# Processing node 56Processing node 68
#
# Processing node 73
# Processing node 58
# Processing node 69
# Processing node 63
# Processing node 57
# Processing node 60
# Processing node 67
# Processing node 45
# Processing node 57
# Processing node 57Processing node 74
#
# Processing node 70Processing node 61
#
# Processing node 51
# Processing node 61
# Processing node 52
# Processing node 51Processing node 67
# Processing node 75
#
# Processing node 62Processing node 58
# Processing node 72
#
# Processing node 51Processing node 59Processing node 69
#
#
# Processing node 54
# Processing node 69
# Processing node 53
# Processing node 45Processing node 70
#
# Processing node 64
# Processing node 61
# Processing node 63Processing node 46
#
# Processing node 58
# Processing node 58
# Processing node 52
# Processing node 62Processing node 62
#
# Processing node 68
# Processing node 73
# Processing node 76
# Processing node 64
# Processing node 60
# Processing node 68
# Processing node 71
# Processing node 55
# Processing node 65
# Processing node 70
# Processing node 65
# Processing node 52
# Processing node 70
# Processing node 54
# Processing node 46Processing node 52
#
# Processing node 71
# Processing node 62
# Processing node 59
# Processing node 63
# Processing node 66
# Processing node 59
# Processing node 74
# Processing node 47
# Processing node 47Processing node 59Processing node 69
#
#
# Processing node 53
# Processing node 72
# Processing node 67
# Processing node 63
# Processing node 48
# Processing node 71
# Processing node 54Processing node 56
#
# Processing node 61
# Processing node 70Processing node 72Processing node 69
#
#
# Processing node 77
# Processing node 64
# Processing node 72Processing node 55Processing node 55
#
#
# Processing node 71
# Processing node 60
# Processing node 49
# Processing node 53
# Processing node 66
# Processing node 63
# Processing node 75
# Processing node 60
# Processing node 53
# Processing node 68
# Processing node 48
# Processing node 60
# Processing node 73Processing node 70Processing node 78
#
#
# Processing node 73
# Processing node 64Processing node 65
#
# Processing node 62
# Processing node 57
# Processing node 50
# Processing node 73Processing node 56Processing node 71
#
#
# Processing node 67
# Processing node 72
# Processing node 61
# Processing node 56
# Processing node 61
# Processing node 76Processing node 49
#
# Processing node 64
# Processing node 54
# Processing node 79
# Processing node 69
# Processing node 54
# Processing node 63
# Processing node 74
# Processing node 61
# Processing node 58
# Processing node 71
# Processing node 51Processing node 74
#
# Processing node 68
# Processing node 66Processing node 73
#
# Processing node 62
# Processing node 72
# Processing node 57
# Processing node 57Processing node 74Processing node 65
#
#
# Processing node 52Processing node 55Processing node 50
#
#
# Processing node 63
# Processing node 62
# Processing node 58
# Processing node 77
# Processing node 70Processing node 65
#
# Processing node 80
# Processing node 64Processing node 75
#
# Processing node 67
# Processing node 62Processing node 64
#
# Processing node 75
# Processing node 55
# Processing node 72
# Processing node 69
# Processing node 74
# Processing node 56Processing node 66
#
# Processing node 59Processing node 73
#
# Processing node 58
# Processing node 75Processing node 78
#
# Processing node 71
# Processing node 53Processing node 51
#
# Processing node 63
# Processing node 59
# Processing node 81
# Processing node 74
# Processing node 66Processing node 54Processing node 76
#
#
# Processing node 76
# Processing node 70
# Processing node 73
# Processing node 57Processing node 56
# Processing node 68
# Processing node 63
#
# Processing node 75Processing node 65
#
# Processing node 67Processing node 59
#
# Processing node 55Processing node 52
#
# Processing node 72
# Processing node 79
# Processing node 76
# Processing node 65
# Processing node 77
# Processing node 73Processing node 64
#
# Processing node 74
# Processing node 60
# Processing node 69
# Processing node 75Processing node 71Processing node 82
#
#
# Processing node 57
# Processing node 64
# Processing node 67
# Processing node 77
# Processing node 76
# Processing node 56Processing node 58
# Processing node 66
#
# Processing node 66
# Processing node 58
# Processing node 60
# Processing node 68
# Processing node 77Processing node 80
#
# Processing node 53Processing node 60
#
# Processing node 75
# Processing node 70
# Processing node 65Processing node 61Processing node 69
#
#
# Processing node 74
# Processing node 76
# Processing node 78
# Processing node 78
# Processing node 68
# Processing node 70
# Processing node 75
# Processing node 57Processing node 65
#
# Processing node 67
# Processing node 77
# Processing node 72
# Processing node 59Processing node 81
#
# Processing node 83
# Processing node 68
# Processing node 59
# Processing node 76
# Processing node 61
# Processing node 66
# Processing node 78Processing node 67
#
# Processing node 62
# Processing node 54
# Processing node 61
# Processing node 69
# Processing node 71
# Processing node 79
# Processing node 55
# Processing node 66
# Processing node 79
# Processing node 58Processing node 77
#
# Processing node 60Processing node 73
#
# Processing node 78Processing node 63
#
# Processing node 71Processing node 82
#
# Processing node 76
# Processing node 77
# Processing node 69Processing node 60
#
# Processing node 78
# Processing node 68Processing node 62
#
# Processing node 79
# Processing node 67
# Processing node 64
# Processing node 84
# Processing node 72
# Processing node 80
# Processing node 80
# Processing node 67Processing node 62
# Processing node 56
# Processing node 69
#
# Processing node 65
# Processing node 70
# Processing node 81
# Processing node 61Processing node 83
#
# Processing node 70
# Processing node 79
# Processing node 59
# Processing node 63
# Processing node 68
# Processing node 77
# Processing node 78Processing node 71Processing node 72
# Processing node 61
#
#
# Processing node 74
# Processing node 79
# Processing node 57
# Processing node 80
# Processing node 68
# Processing node 73
# Processing node 85
# Processing node 81
# Processing node 80
# Processing node 84
# Processing node 66
# Processing node 71
# Processing node 80
# Processing node 62
# Processing node 82Processing node 79
#
# Processing node 62
# Processing node 85
# Processing node 72
# Processing node 60Processing node 81
#
# Processing node 58
# Processing node 73
# Processing node 69
# Processing node 83Processing node 69
#
# Processing node 78
# Processing node 86
# Processing node 75
# Processing node 81
# Processing node 84
# Processing node 82Processing node 70
#
# Processing node 74
# Processing node 67Processing node 70
#
# Processing node 86
# Processing node 63Processing node 82
#
# Processing node 64
# Processing node 63Processing node 80
#
# Processing node 82
# Processing node 59Processing node 61Processing node 74
#
#
# Processing node 72
# Processing node 81
# Processing node 83
# Processing node 70
# Processing node 63
# Processing node 73
# Processing node 82
# Processing node 79Processing node 84
#
# Processing node 83Processing node 71
#
# Processing node 76
# Processing node 87Processing node 74
#
# Processing node 71
# Processing node 60Processing node 85
#
# Processing node 84Processing node 65Processing node 64
# Processing node 83
#
#
# Processing node 68
# Processing node 75
# Processing node 75Processing node 87
#
# Processing node 86
# Processing node 81
# Processing node 85
# Processing node 62
# Processing node 64
# Processing node 64
# Processing node 87Processing node 71
#
# Processing node 83Processing node 73
#
# Processing node 77
# Processing node 72
# Processing node 85
# Processing node 88
# Processing node 72
# Processing node 84
# Processing node 86
# Processing node 88Processing node 75
#
# Processing node 76Processing node 72
#
# Processing node 65
# Processing node 66Processing node 88
#
# Processing node 61
# Processing node 63Processing node 76
#
# Processing node 82
# Processing node 84
# Processing node 89
# Processing node 73
# Processing node 86
# Processing node 78
# Processing node 65
# Processing node 65
# Processing node 74
# Processing node 87
# Processing node 87
# Processing node 89
# Processing node 76
# Processing node 73Processing node 89
#
# Processing node 85
# Processing node 88
# Processing node 66
# Processing node 80
# Processing node 62Processing node 77
#
# Processing node 90Processing node 69
#
# Processing node 77Processing node 73
#
# Processing node 85
# Processing node 89
# Processing node 67
# Processing node 83Processing node 64
#
# Processing node 74
# Processing node 74Processing node 75
#
# Processing node 88
# Processing node 79
# Processing node 66
# Processing node 66
# Processing node 91
# Processing node 90
# Processing node 89
# Processing node 86Processing node 77
#
# Processing node 90
# Processing node 74
# Processing node 78
# Processing node 84
# Processing node 92
# Processing node 65
# Processing node 68
# Processing node 70Processing node 87
#
# Processing node 90
# Processing node 86
# Processing node 90Processing node 63
# Processing node 75
#
# Processing node 81
# Processing node 80
# Processing node 76
# Processing node 78
# Processing node 67
# Processing node 67
# Processing node 91
# Processing node 85
# Processing node 91Processing node 78
#
# Processing node 66
# Processing node 75Processing node 87
#
# Processing node 76Processing node 79
#
# Processing node 71
# Processing node 93
# Processing node 91
# Processing node 81Processing node 88
#
# Processing node 91
# Processing node 67Processing node 75
#
# Processing node 69
# Processing node 77
# Processing node 82
# Processing node 79
# Processing node 68
# Processing node 64
# Processing node 76
# Processing node 92
# Processing node 67
# Processing node 92
# Processing node 89
# Processing node 68
# Processing node 92
# Processing node 88Processing node 76
#
# Processing node 94
# Processing node 90
# Processing node 86
# Processing node 80Processing node 79
#
# Processing node 72
# Processing node 78
# Processing node 68
# Processing node 69
# Processing node 70
# Processing node 93
# Processing node 93Processing node 82
#
# Processing node 68
# Processing node 77
# Processing node 77Processing node 69
#
# Processing node 83
# Processing node 80
# Processing node 69Processing node 65
#
# Processing node 94
# Processing node 93
# Processing node 87Processing node 89
#
# Processing node 95
# Processing node 66
# Processing node 73
# Processing node 77Processing node 70
# Processing node 91
# Processing node 95
#
# Processing node 92Processing node 69
# Processing node 80
#
# Processing node 94Processing node 70
#
# Processing node 70
# Processing node 79Processing node 92Processing node 78
#
# Processing node 96
#
# Processing node 81
# Processing node 71
# Processing node 83
# Processing node 90Processing node 93
#
# Processing node 84
# Processing node 71
# Processing node 81
# Processing node 78
# Processing node 94
# Processing node 88
# Processing node 72
# Processing node 71Processing node 74
#
# Processing node 95
# Processing node 96Processing node 71
#
# Processing node 67
# Processing node 93
# Processing node 73Processing node 70
#
# Processing node 81
# Processing node 82
# Processing node 78
# Processing node 80Processing node 97
#
# Processing node 72
# Processing node 97
# Processing node 68
# Processing node 79
# Processing node 98
# Processing node 91Processing node 84
#
# Processing node 85Processing node 72
#
# Processing node 82
# Processing node 94
# Processing node 75Processing node 79Processing node 69
#
#
# Processing node 89
# Processing node 96
# Processing node 74
# Processing node 99
# Processing node 83
# Processing node 82
# Processing node 85
# Processing node 79Processing node 98
#
# Processing node 73
# Processing node 70Processing node 94
#
# Processing node 71
# Processing node 84Processing node 80
#
# Processing node 83Processing node 86
#
# Processing node 74Processing node 81
# Processing node 72
#
# Processing node 92
# Processing node 71
# Processing node 95
# Processing node 90Processing node 75
#
# Processing node 87
# Processing node 73
# Processing node 76Processing node 75Processing node 100
#
#
# Processing node 73
# Processing node 83
# Processing node 72Processing node 97
#
# Processing node 86
# Processing node 76
# Processing node 95Processing node 80
#
# Processing node 80
# Processing node 88Processing node 73
#
# Processing node 77
# Processing node 84Processing node 99
#
# Processing node 96Processing node 95
#
# Processing node 74
# Processing node 72
# Processing node 91
# Processing node 78
# Processing node 82Processing node 93
# Processing node 76
#
# Processing node 101
# Processing node 81
# Processing node 84Processing node 74
#
# Processing node 77
# Processing node 87Processing node 75
#
# Processing node 85
# Processing node 82
# Processing node 74
# Processing node 98
# Processing node 76
# Processing node 81
# Processing node 96
# Processing node 85Processing node 89
#
# Processing node 81
# Processing node 96
# Processing node 94
# Processing node 100
# Processing node 82Processing node 77
#
# Processing node 75Processing node 97Processing node 97
#
#
# Processing node 83Processing node 92Processing node 88
#
#
# Processing node 79
# Processing node 85
# Processing node 73
# Processing node 102
# Processing node 78
# Processing node 75
# Processing node 86
# Processing node 99
# Processing node 83
# Processing node 86
# Processing node 95Processing node 83
#
# Processing node 90
# Processing node 93
# Processing node 98
# Processing node 80
# Processing node 82Processing node 101
# Processing node 78
#
# Processing node 77
# Processing node 97Processing node 79
#
# Processing node 86
# Processing node 89
# Processing node 76
# Processing node 103
# Processing node 84
# Processing node 100
# Processing node 87
# Processing node 76Processing node 84
#
# Processing node 104
# Processing node 98
# Processing node 84Processing node 74
#
# Processing node 87Processing node 91
#
# Processing node 96
# Processing node 81
# Processing node 79
# Processing node 105
# Processing node 98
# Processing node 94
# Processing node 99Processing node 78
# Processing node 90
# Processing node 87
# Processing node 77
#
# Processing node 85
# Processing node 83
# Processing node 102Processing node 80
#
# Processing node 85
# Processing node 88
# Processing node 101Processing node 75
#
# Processing node 77
# Processing node 85
# Processing node 99
# Processing node 82
# Processing node 88
# Processing node 95
# Processing node 92
# Processing node 78
# Processing node 97
# Processing node 106Processing node 88Processing node 80Processing node 99
#
#
#
# Processing node 91
# Processing node 86
# Processing node 100
# Processing node 103
# Processing node 89Processing node 79Processing node 84
#
# Processing node 86
#
# Processing node 100
# Processing node 81
# Processing node 107Processing node 102
#
# Processing node 86
# Processing node 83
# Processing node 101Processing node 89
#
# Processing node 76
# Processing node 100
# Processing node 96
# Processing node 108
# Processing node 78
# Processing node 98
# Processing node 93Processing node 89
#
# Processing node 80Processing node 79
#
# Processing node 104
# Processing node 90
# Processing node 101Processing node 87
#
# Processing node 92
# Processing node 87
# Processing node 85
# Processing node 82
# Processing node 94Processing node 102Processing node 87
#
#
# Processing node 103
# Processing node 93Processing node 97
#
# Processing node 79
# Processing node 84
# Processing node 90
# Processing node 77Processing node 101
#
# Processing node 95
# Processing node 109Processing node 80Processing node 105
#
#
# Processing node 81Processing node 103
#
# Processing node 98
# Processing node 102
# Processing node 86
# Processing node 99
# Processing node 90
# Processing node 110
# Processing node 81Processing node 83
#
# Processing node 88
# Processing node 88Processing node 94
#
# Processing node 104Processing node 88
#
# Processing node 111
# Processing node 96
# Processing node 102
# Processing node 95Processing node 81
#
# Processing node 80
# Processing node 104Processing node 85
#
# Processing node 91
# Processing node 103
# Processing node 97Processing node 78
# Processing node 91
#
# Processing node 91Processing node 84
# Processing node 87
#
# Processing node 82
# Processing node 106Processing node 103
#
# Processing node 99
# Processing node 100
# Processing node 98
# Processing node 92
# Processing node 83
# Processing node 89Processing node 89Processing node 82
#
#
# Processing node 89
# Processing node 82
# Processing node 105Processing node 92
#
# Processing node 84
# Processing node 112
# Processing node 105
# Processing node 104
# Processing node 79
# Processing node 85Processing node 96
#
# Processing node 81Processing node 107
# Processing node 106
#
# Processing node 86Processing node 100
#
# Processing node 101
# Processing node 92
# Processing node 97
# Processing node 88
# Processing node 93
# Processing node 99Processing node 90Processing node 90
#
#
# Processing node 104
# Processing node 83
# Processing node 90
# Processing node 83
# Processing node 85
# Processing node 100
# Processing node 105
# Processing node 93
# Processing node 82Processing node 107
# Processing node 106
#
# Processing node 113
# Processing node 80
# Processing node 86
# Processing node 89Processing node 94Processing node 108
#
#
# Processing node 93
# Processing node 101Processing node 87
#
# Processing node 102
# Processing node 98
# Processing node 91
# Processing node 91
# Processing node 84
# Processing node 101
# Processing node 102
# Processing node 91
# Processing node 106
# Processing node 83Processing node 114
# Processing node 103
#
# Processing node 94Processing node 86
#
# Processing node 102Processing node 87
#
# Processing node 105Processing node 108
#
# Processing node 84
# Processing node 94Processing node 88
#
# Processing node 84
# Processing node 81Processing node 92
# Processing node 107
#
# Processing node 109
# Processing node 95
# Processing node 92
# Processing node 85
# Processing node 90Processing node 92
#
# Processing node 103
# Processing node 99
# Processing node 108
# Processing node 85
# Processing node 104Processing node 87
# Processing node 106
#
# Processing node 86
# Processing node 115
# Processing node 107
# Processing node 88
# Processing node 89Processing node 109
#
# Processing node 95
# Processing node 95
# Processing node 103
# Processing node 89
# Processing node 110
# Processing node 93
# Processing node 110Processing node 93
#
# Processing node 82
# Processing node 85
# Processing node 96
# Processing node 93
# Processing node 87Processing node 104
#
# Processing node 91
# Processing node 100Processing node 116
#
# Processing node 108
# Processing node 86
# Processing node 105
# Processing node 88
# Processing node 107Processing node 96
#
# Processing node 96Processing node 109
# Processing node 111
#
# Processing node 94
# Processing node 90
# Processing node 109
# Processing node 83Processing node 90Processing node 104Processing node 101
#
#
#
# Processing node 87
# Processing node 111
# Processing node 94Processing node 105
# Processing node 92
# Processing node 88
#
# Processing node 86
# Processing node 84Processing node 97Processing node 102
# Processing node 88
#
#
# Processing node 117
# Processing node 106Processing node 94Processing node 112
#
#
# Processing node 97
# Processing node 95
# Processing node 93Processing node 91
#
# Processing node 113
# Processing node 85
# Processing node 89
# Processing node 112Processing node 97
#
# Processing node 110
# Processing node 110
# Processing node 114
# Processing node 91
# Processing node 103
# Processing node 87
# Processing node 105
# Processing node 89
# Processing node 108Processing node 111
#
# Processing node 115Processing node 95
#
# Processing node 89
# Processing node 98
# Processing node 92
# Processing node 118
# Processing node 107
# Processing node 98Processing node 90
# Processing node 95
#
# Processing node 86
# Processing node 116
# Processing node 98Processing node 96
#
# Processing node 111
# Processing node 92
# Processing node 99Processing node 94
#
# Processing node 108Processing node 91
# Processing node 90Processing node 96
#
#
# Processing node 117
# Processing node 88
# Processing node 97Processing node 113
# Processing node 104
#
# Processing node 106
# Processing node 96
# Processing node 95
# Processing node 93
# Processing node 106
# Processing node 89
# Processing node 109Processing node 112
#
# Processing node 92
# Processing node 97
# Processing node 90
# Processing node 87
# Processing node 119
# Processing node 99Processing node 98
#
# Processing node 100Processing node 113
#
# Processing node 91
# Processing node 118
# Processing node 112
# Processing node 97Processing node 105
#
# Processing node 93
# Processing node 91
# Processing node 99
# Processing node 109
# Processing node 107
# Processing node 114
# Processing node 92Processing node 96
#
# Processing node 119
# Processing node 98
# Processing node 90
# Processing node 107
# Processing node 110
# Processing node 93
# Processing node 94Processing node 93Processing node 114
#
#
# Processing node 108
# Processing node 88
# Processing node 120
# Processing node 99
# Processing node 99Processing node 100
#
# Processing node 101
# Processing node 94
# Processing node 98Processing node 109
#
# Processing node 111
# Processing node 94
# Processing node 120
# Processing node 110
# Processing node 121
# Processing node 106Processing node 110
#
# Processing node 100Processing node 95
#
# Processing node 113Processing node 111
#
# Processing node 94
# Processing node 100
# Processing node 92
# Processing node 111
# Processing node 115
# Processing node 115
# Processing node 107
# Processing node 96Processing node 101
#
# Processing node 97
# Processing node 91Processing node 100
#
# Processing node 108
# Processing node 95Processing node 112
#
# Processing node 102Processing node 89
#
# Processing node 116
# Processing node 121
# Processing node 101
# Processing node 99
# Processing node 95
# Processing node 122Processing node 112
#
# Processing node 93
# ...
# Processing node 199
# Debuging boldProcessing node 0
# Processing node 1
# Processing node 2
# Processing node 3
# Processing node 4
# Processing node 5
# Processing node 6
# Processing node 7
# Processing node 8
# Processing node 9
# Processing node 10
# Processing node 11
# Processing node 12
# Processing node 13
# Processing node 14
# Processing node 15
# Processing node 16
# Processing node 17
# Processing node 18
# Processing node 19
# Processing node 0
# Processing node 20
# Processing node 1
# Processing node 21
# Processing node 2
# Processing node 3
# Processing node 22
# Processing node 4
# Processing node 5
# Processing node 6
# Processing node 23
# Processing node 7
# Processing node 8
# Processing node 9
# Processing node 10
# Processing node 24
# Processing node 11
# Processing node 12
# Processing node 25
# Processing node 13
# Processing node 26
# Processing node 14
# Processing node 15
# Processing node 27
# Processing node 28
# Processing node 16
# Processing node 17Processing node 29
#
# Processing node 30
# Processing node 18
# Processing node 31
# Processing node 19
# Processing node 20
# Processing node 32
# Processing node 33
# Processing node 21
# Processing node 34
# Processing node 22
# Processing node 35
# Processing node 23
# Processing node 36
# Processing node 24
# Processing node 37
# Processing node 25
# Processing node 38
# Processing node 26
# Processing node 39
# Processing node 27
# Processing node 40
# Processing node 28
# Processing node 41
# Processing node 29
# Processing node 42
# Processing node 30
# Processing node 31
# Processing node 43
# Processing node 44
# Processing node 32
# Processing node 45
# Processing node 33
# Processing node 34
# Processing node 46
# Processing node 35
# Processing node 47
# Processing node 36
# Processing node 48
# Processing node 49
# Processing node 37
# Processing node 50
# Processing node 38
# Processing node 51
# Processing node 39
# Processing node 52
# Processing node 40
# Processing node 41
# Processing node 53
# Processing node 42
# Processing node 54
# Processing node 43
# Processing node 55
# Processing node 44
# Processing node 56
# Processing node 45
# Processing node 57
# Processing node 46
# Processing node 58
# Processing node 47
# Processing node 59
# Processing node 60
# Processing node 48
# Processing node 61
# Processing node 49
# Processing node 62
# Processing node 50
# Processing node 63
# Processing node 51
# Processing node 52
# Processing node 64
# Processing node 53
# Processing node 65
# Processing node 54
# Processing node 66
# Processing node 55
# Processing node 67
# Processing node 56
# Processing node 68
# Processing node 57Processing node 69
#
# Processing node 70Processing node 58
#
# Processing node 71
# Processing node 59
# Processing node 72
# Processing node 60
# Processing node 73
# Processing node 61
# Processing node 62
# Processing node 74
# Processing node 63
# Processing node 75
# Processing node 64
# Processing node 76
# Processing node 65
# Processing node 77
# Processing node 66
# Processing node 78
# Processing node 67
# Processing node 79
# Processing node 68
# Processing node 80
# Processing node 69
# Processing node 81
# Processing node 70
# Processing node 71Processing node 82
#
# Processing node 72
# Processing node 83
# Processing node 73
# Processing node 84
# Processing node 85
# Processing node 74
# Processing node 86
# Processing node 75
# Processing node 87
# Processing node 76
# Processing node 88
# Processing node 77
# Processing node 89
# Processing node 78
# Processing node 90
# Processing node 79
# Processing node 91
# Processing node 80Processing node 92
#
# Processing node 93
# Processing node 81
# Processing node 94
# Processing node 95Processing node 82
#
# Processing node 96
# Processing node 83
# Processing node 97
# Processing node 84
# Processing node 85
# Processing node 98
# Processing node 86
# Processing node 99
# Processing node 87
# Processing node 100
# Processing node 88
# Processing node 101
# Processing node 89
# Processing node 90Processing node 102
#
# Processing node 103
# Processing node 91
# Processing node 92
# Processing node 104
# Processing node 105
# Processing node 93
# Processing node 106
# Processing node 94
# Processing node 107
# Processing node 95
# Processing node 96
# Processing node 108
# Processing node 109
# Processing node 97
# Processing node 110
# Processing node 98
# Processing node 111
# Processing node 99
# Processing node 100
# Processing node 112
# Processing node 113
# Processing node 101
# Processing node 114
# Processing node 102
# Processing node 115
# Processing node 116
# Processing node 103
# Processing node 117
# Processing node 104
# Processing node 118
# Processing node 105
# Processing node 119
# Processing node 106
# Processing node 120
# Processing node 107
# Processing node 121
# Processing node 108
# Processing node 122
# Processing node 109
# Processing node 123
# Processing node 110
# Processing node 124
# Processing node 111
# Processing node 125
# Processing node 112
# Processing node 126
# Processing node 113
# Processing node 127
# Processing node 128
# Processing node 114
# Processing node 129
# Processing node 130
# Processing node 115
# Processing node 131
# Processing node 132
# Processing node 133
# Processing node 116
# Processing node 134
# Processing node 117
# Processing node 135
# Processing node 118
# Processing node 136
# Processing node 137
# Processing node 119
# Processing node 138
# Processing node 139
# Processing node 120
# Processing node 140
# Processing node 121
# Processing node 141
# Processing node 142
# Processing node 143
# Processing node 122
# Processing node 144
# Processing node 145
# Processing node 146
# Processing node 123
# Processing node 147
# Processing node 148
# Processing node 149
# Processing node 150Processing node 124
#
# Processing node 151
# Processing node 125
# Processing node 152
# Processing node 126
# Processing node 127Processing node 153
#
# Processing node 154Processing node 128
#
# Processing node 129
# Processing node 130
# Processing node 155
# Processing node 131
# Processing node 156
# Processing node 157
# Processing node 158
# Processing node 132
# Processing node 159Processing node 133
#
# Processing node 160
# Processing node 134
# Processing node 161
# Processing node 135
# Processing node 136
# Processing node 162
# Processing node 137
# Processing node 163
# Processing node 164
# Processing node 138
# Processing node 165
# Processing node 166
# Processing node 167
# Processing node 139
# Processing node 168
# Processing node 169
# Processing node 140
# Processing node 141
# Processing node 170
# Processing node 142
# Processing node 143
# Processing node 144
# Processing node 171
# Processing node 145
# Processing node 172
# Processing node 146
# Processing node 173
# Processing node 147
# Processing node 174
# Processing node 175
# Processing node 148
# Processing node 176
# Processing node 149
# Processing node 150
# Processing node 177
# Processing node 151
# Processing node 178
# Processing node 152
# Processing node 179
# Processing node 153
# Processing node 154
# Processing node 180
# Processing node 155
# Processing node 156
# Processing node 181
# Processing node 157
# Processing node 158
# Processing node 182
# Processing node 159
# Processing node 160
# Processing node 183
# Processing node 161
# Processing node 162
# Processing node 163
# Processing node 164
# Processing node 184
# Processing node 165
# Processing node 185
# Processing node 166
# Processing node 167
# Processing node 186
# Processing node 168
# Processing node 169
# Processing node 187
# Processing node 170
# Processing node 171
# Processing node 188
# Processing node 189Processing node 172
#
# Processing node 173
# Processing node 174
# Processing node 190
# Processing node 175
# Processing node 176
# Processing node 191
# Processing node 192
# Processing node 193
# Processing node 177
# Processing node 178
# Processing node 179
# Processing node 194
# Processing node 180
# Processing node 195
# Processing node 181
# Processing node 182
# Processing node 196
# Processing node 183
# Processing node 197
# Processing node 184Processing node 198
#
# Processing node 199
# Processing node 185
# Processing node 186
# Processing node 187
# Processing node 188
# Processing node 189
# Processing node 190
# Processing node 191
# Debuging boldProcessing node 192
# Processing node 193
# Processing node 194
# Processing node 195
# Processing node 196
# Processing node 197
# Processing node 198
# Processing node 199
# Debuging boldProcessing node 0
# Processing node 1
# Processing node 2
# Processing node 3
# Processing node 4
# Processing node 5
# Processing node 6
# Processing node 7
# Processing node 8
# Processing node 9
# Processing node 10
# Processing node 11
# Processing node 12
# Processing node 13
# Processing node 14
# Processing node 15
# Processing node 16
# Processing node 17
# Processing node 18
# Processing node 19
# Processing node 20
# Processing node 21
# Processing node 0
# Processing node 22
# Processing node 23
# Processing node 24
# Processing node 1
# Processing node 25
# Processing node 26
# Processing node 27
# Processing node 2
# Processing node 28
# Processing node 29Processing node 3
#
# Processing node 30
# Processing node 4
# Processing node 31
# Processing node 5Processing node 32
#
# Processing node 6
# Processing node 33
# Processing node 7
# Processing node 34
# Processing node 8
# Processing node 35
# Processing node 9
# Processing node 36
# Processing node 10
# Processing node 11
# Processing node 37
# Processing node 12Processing node 38
#
# Processing node 13
# Processing node 39
# Processing node 14
# Processing node 40
# Processing node 41
# Processing node 42
# Processing node 15
# Processing node 16
# Processing node 17
# Processing node 43Processing node 18
#
# Processing node 19
# Processing node 20
# Processing node 21
# Processing node 44
# Processing node 22
# Processing node 23
# Processing node 45
# Processing node 24
# Processing node 25
# Processing node 46
# Processing node 26
# Processing node 27
# Processing node 28
# Processing node 47
# Processing node 29
# Processing node 48
# Processing node 30
# Processing node 49
# Processing node 31
# Processing node 32
# Processing node 33
# Processing node 50
# Processing node 51
# Processing node 52
# Processing node 34
# Processing node 35
# Processing node 36
# Processing node 53
# Processing node 54
# Processing node 55
# Processing node 56
# Processing node 37
# Processing node 57
# Processing node 38
# Processing node 58
# Processing node 39
# Processing node 59
# Processing node 40
# Processing node 60
# Processing node 41
# Processing node 42
# Processing node 61
# Processing node 43
# Processing node 62
# Processing node 63
# Processing node 64
# Processing node 65
# Processing node 44
# Processing node 66
# Processing node 45
# Processing node 67
# Processing node 46Processing node 68
#
# Processing node 69
# Processing node 47
# Processing node 70
# Processing node 48
# Processing node 71
# Processing node 49
# Processing node 72
# Processing node 50
# Processing node 73
# Processing node 51
# Processing node 52Processing node 74
#
# Processing node 53
# Processing node 75
# Processing node 54
# Processing node 76
# Processing node 55
# Processing node 56
# Processing node 57
# Processing node 58
# Processing node 77
# Processing node 59Processing node 78
#
# Processing node 79
# Processing node 60
# Processing node 61
# Processing node 80
# Processing node 62
# Processing node 81
# Processing node 63
# Processing node 82
# Processing node 64
# Processing node 83
# Processing node 65
# Processing node 84
# Processing node 66
# Processing node 85
# Processing node 67
# Processing node 86
# Processing node 68
# Processing node 87
# Processing node 88
# Processing node 69
# Processing node 89
# Processing node 70
# Processing node 90
# Processing node 71
# Processing node 91
# Processing node 92
# Processing node 72
# Processing node 93
# Processing node 73
# Processing node 94
# Processing node 74
# Processing node 95
# Processing node 75
# Processing node 76
# Processing node 96
# Processing node 77
# Processing node 97
# Processing node 78
# Processing node 98
# Processing node 99
# Processing node 79
# Processing node 100
# Processing node 80
# Processing node 101
# Processing node 81
# Processing node 102
# Processing node 103
# Processing node 104
# Processing node 82
# Processing node 83
# Processing node 105
# Processing node 84
# Processing node 85
# Processing node 106
# Processing node 86
# Processing node 87
# Processing node 88
# Processing node 89
# Processing node 107
# Processing node 90
# Processing node 108
# Processing node 109
# Processing node 91
# Processing node 92
# Processing node 110
# Processing node 93
# Processing node 111
# Processing node 94
# Processing node 112
# Processing node 95
# Processing node 113
# Processing node 114
# Processing node 96
# Processing node 115
# Processing node 97
# Processing node 116
# Processing node 98
# Processing node 117
# Processing node 99
# Processing node 118
# Processing node 100
# Processing node 101
# Processing node 119
# Processing node 120
# Processing node 102
# Processing node 121
# Processing node 103
# Processing node 122
# Processing node 104
# Processing node 123Processing node 105
#
# Processing node 124Processing node 106
#
# Processing node 107
# Processing node 125
# Processing node 108
# Processing node 126
# Processing node 109
# Processing node 127
# Processing node 110
# Processing node 128
# Processing node 111
# Processing node 129
# Processing node 112
# Processing node 130
# Processing node 113
# Processing node 131
# Processing node 114
# Processing node 132
# Processing node 115
# Processing node 133
# Processing node 116
# Processing node 134
# Processing node 117
# Processing node 135
# Processing node 118
# Processing node 136
# Processing node 137
# Processing node 119
# Processing node 138
# Processing node 120
# Processing node 139
# Processing node 121
# Processing node 122
# Processing node 123
# Processing node 124
# Processing node 140
# Processing node 125
# Processing node 141
# Processing node 126
# Processing node 142
# Processing node 127
# Processing node 143
# Processing node 128
# Processing node 129
# Processing node 144
# Processing node 145
# Processing node 130
# Processing node 146
# Processing node 131
# Processing node 132Processing node 147
#
# Processing node 148
# Processing node 133
# Processing node 134Processing node 149
#
# Processing node 150
# Processing node 135
# Processing node 151
# Processing node 136
# Processing node 137
# Processing node 152
# Processing node 138
# Processing node 153
# Processing node 139Processing node 154
#
# Processing node 155
# Processing node 140
# Processing node 156
# Processing node 141
# Processing node 157
# Processing node 142
# Processing node 158
# Processing node 143
# Processing node 159
# Processing node 144
# Processing node 160
# Processing node 161
# Processing node 145Processing node 162
#
# Processing node 146Processing node 163
#
# Processing node 164
# Processing node 147
# Processing node 165
# Processing node 148
# Processing node 149
# Processing node 166
# Processing node 150
# Processing node 167
# Processing node 151
# Processing node 168Processing node 152
#
# Processing node 169
# Processing node 153
# Processing node 170
# Processing node 154
# Processing node 171
# Processing node 155
# Processing node 172
# Processing node 156
# Processing node 173
# Processing node 157
# Processing node 174
# Processing node 158
# Processing node 175
# Processing node 159
# Processing node 176
# Processing node 160
# Processing node 177
# Processing node 178
# Processing node 161
# Processing node 179
# Processing node 162
# Processing node 163
# Processing node 180
# Processing node 164
# Processing node 181
# Processing node 165
# Processing node 182
# Processing node 166
# Processing node 167
# Processing node 183
# Processing node 168
# Processing node 184
# Processing node 169
# Processing node 185Processing node 170
#
# Processing node 186Processing node 171
#
# Processing node 172
# Processing node 187
# Processing node 173
# Processing node 188
# Processing node 174
# Processing node 189
# Processing node 175
# Processing node 190
# Processing node 176
# Processing node 191
# Processing node 177
# Processing node 192
# Processing node 178
# Processing node 193
# Processing node 179
# Processing node 194
# Processing node 180
# Processing node 195
# Processing node 181
# Processing node 196
# Processing node 182
# Processing node 197Processing node 183
#
# Processing node 198
# Processing node 184
# Processing node 199
# Processing node 185
# Processing node 186
# Processing node 187
# Processing node 188
# Processing node 189
# Processing node 190
# Processing node 191
# Processing node 192
# Processing node 193
# Processing node 194
# Processing node 195
# Processing node 196
# Processing node 197
# Processing node 198
# Processing node 199
# /home/ivan.mindlin/.conda/envs/fic/lib/python3.10/site-packages/numpy/lib/npyio.py:518: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
# Out:
# (200,)
